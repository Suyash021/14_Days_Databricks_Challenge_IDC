# %%
dbutils.widgets.dropdown(
    "layer", 
    "bronze",
    ["bronze", "silver", "gold"]
)

layer = dbutils.widgets.get("layer")
print(f"Running Layer:{layer}")

# dbutils.widgets.text("db", "dbdemos")
# dbutils.widgets.text("table", "events")
# dbutils.widgets.text("topic", "events")

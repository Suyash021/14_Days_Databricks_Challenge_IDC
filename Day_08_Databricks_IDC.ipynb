# %%
# %sql
-- # Create catalog & schemas 

CREATE catalog IF NOT EXISTS ecommerce_IDC;

# %%
# %sql
use catalog ecommerce_idc;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
# %sql
USE CATALOG ecommerce_idc;

CREATE TABLE IF NOT EXISTS ecommerce_idc.bronze.events
USING DELTA 
AS SELECT * FROM workspace.ecommerce.bronze_table;

-- CREATE TABLE IF NOT EXISTS ecommerce_idc.silver.events
-- USING DELTA 
-- AS SELECT * FROM delta.`/Volumes/ecommerce_idc/silver/events`;

-- CREATE TABLE IF NOT EXISTS ecommerce_idc.gold.products_kpis
-- USING DELTA 
-- AS SELECT * FROM delta.`/Volumes/ecommerce_idc/gold/products_kpis`;

# %%
# %sql
SHOW SCHEMAS;

# %%
# %sql
SELECT * FROM workspace.ecommerce.gold_product_sales;

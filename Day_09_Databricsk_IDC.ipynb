# %%
# %sql
-- WITH daily AS (
--   SELECT event_time, SUM(price) as pri
--   FROM ecommerce_idc.bronze.events GROUP BY event_time
-- )
-- SELECT event_time, pri,
--   AVG(pri) OVER (ORDER BY event_time ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) as ma7
-- FROM daily;
SELECT * FROM workspace.default.events_delta;
